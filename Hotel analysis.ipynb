# %% [markdown]
# DAY 3

# %%
def sum_list():
  list=[1,7,9,3,6]
  sum=0
  for i in range(list):
    sum=sum+i
  return(sum)
print(sum_list())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ebd137373443> in <cell line: 7>()
#       5     sum=sum+i
#       6   return(sum)
# ----> 7 print(sum_list())
#
# <ipython-input-7-ebd137373443> in sum_list()
#       2   list=[1,7,9,3,6]
#       3   sum=0
# ----> 4   for i in range(list):
#       5     sum=sum+i
#       6   return(sum)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
#write a function that will give sum of numbers in the list
def sum_list():
  list=[1,7,9,3,6]
  sum=0
  for i in list:
    sum=sum+i
  return(sum)
print(sum_list())
# Out:
# 26

# %%
#write a function that will give sum of numbers in the list without using any predefined function.
def sum_list(x):
  sum=0
  for i in x:
    sum=sum+i
  return(sum)
print(sum_list([1,7,9,3,6]))
# Out:
# 26

# %%
x="tmv"
type(x)
# Out:
# str

# %%
#write the function that will give the count of vowels in the given string/text,not to use predefined libraries/ function.
def count_str():
  str1="hello, welcome"
  vowels="aeiou"
  count=0
  for i in str1:
    if i in vowels:
      count=count+1
  return(count)
print(count_str())
# Out:
# 5

# %%
def count_str(x):
  count=0
  x=x.lower()
  vowels=['a','e','i','o','u']
  for i in x:
    if i in vowels:
      count=count+1
  return count
print(count_str("hellowelcome"))
# Out:
# 5

# %%
def count_str(x):
  c=0
  v=['a','e','i','o','u']
  for i in x:
    if i in v:
      c=c+1
  return c
count_str("hellowelcome")
# Out:
# 5

# %% [markdown]
# # Reading bookings data in a datagrame

# %%
import pandas as pd
df_bookings=pd.read_csv("fact_bookings.csv")
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
x=list[df_bookings.room_category.unique()]

# %%
print(x)
# Out:
# list[array(['RT1', 'RT2', 'RT3', 'RT4', nan], dtype=object)]

# %%
y=tuple[df_bookings.room_category.unique()]
print(y)
# Out:
# tuple[array(['RT1', 'RT2', 'RT3', 'RT4', nan], dtype=object)]

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 12.3+ MB

# %%
df_bookings.isna().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_bookings['no_guests'].fillna(3,inplace=True)

# %%
df_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134590 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 12.3+ MB

# %% [markdown]
# #Hotel analysis

# %%
df_hotels=pd.read_csv("dim_hotels.csv")
df_date=pd.read_csv("dim_date.csv")
df_rooms=pd.read_csv("dim_rooms.csv")
df_agg_bookings=pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_hotels.tail(3)
# Out:
#     property_id  property_name  category       city
# 22        19562      Atliq Bay    Luxury  Bangalore
# 23        19563   Atliq Palace  Business  Bangalore
# 24        17564  Atliq Seasons  Business     Mumbai

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.unique()
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Bangalore'], dtype=object)

# %%
df_hotels.city.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_hotels.city.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #find out unique property ids in aggregate bookings dataset

# %%
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %% [markdown]
# find out total bookings per property id

# %%
x=pd.DataFrame(df_agg_bookings.groupby("property_id")["successful_bookings"].sum())
x
# Out:
#              successful_bookings
# property_id
# 16558                       3153
# 16559                       7338
# 16560                       4693
# 16561                       4418
# 16562                       4820
# 16563                       7211
# 17558                       5053
# 17559                       6142
# 17560                       6013
# 17561                       5183
# 17562                       3424
# 17563                       6337
# 17564                       3982
# 18558                       4475
# 18559                       5256
# 18560                       6638
# 18561                       6458
# 18562                       7333
# 18563                       4737
# 19558                       4400
# 19559                       4729
# 19560                       6079
# 19561                       5736
# 19562                       5812
# 19563                       5413

# %%
df_agg_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %% [markdown]
# find out days on which bookings are greater than capacity

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %% [markdown]
# find out properties that have highest capacity

# %%
y=df_agg_bookings.groupby("property_id")["capacity"].sum()
y
# Out:
# property_id
# 16558     4784.0
# 16559    11132.0
# 16560     8740.0
# 16561     6716.0
# 16562     9016.0
# 16563    10764.0
# 17558     9384.0
# 17559     9292.0
# 17560    11316.0
# 17561     7794.0
# 17562     7616.0
# 17563     9568.0
# 17564     8924.0
# 18558     8372.0
# 18559    11776.0
# 18560    10028.0
# 18561     9844.0
# 18562    11132.0
# 18563     8924.0
# 19558     9844.0
# 19559     8740.0
# 19560     9108.0
# 19561    10764.0
# 19562     8832.0
# 19563    10120.0
# Name: capacity, dtype: float64

# %%
y.max()
# Out:
# 11776.0

# %%
df_agg_bookings.capacity.max()
# Out:
# 50.0

# %%
df_agg_bookings[df_agg_bookings.capacity==df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# outlier removal in revenue generated

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.median()
# Out:
# (15378.05412734973, 13500.0)

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
higher_limit=avg+3*std
higher_limit
# Out:
# 294486.17014021333

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -263730.06188551383

# %%
df_bookings[df_bookings.revenue_generated<=0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df1=df_bookings[df_bookings.revenue_generated>higher_limit]
df1
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df1.shape
# Out:
# (5, 12)

# %%
df2=df_bookings[df_bookings.revenue_generated<=higher_limit]
df2.shape
# Out:
# (134585, 12)

# %% [markdown]
# in aggreagte bookings find columns that have null values.fill these values with whenever you think is the appropriate substitute(possible way is to use mean or median)

# %%
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agg_bookings.capacity.median()
# Out:
# 25.0

# %% [markdown]
# #Day 3-2

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %%
df_agg_bookings["occ_pct"]=df_agg_bookings.apply(lambda row:row["successful_bookings"]/row["capacity"],axis=1)   #occ_pct=occupation percentage
df_agg_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9198 non-null   float64
#  5   occ_pct              9198 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 431.4+ KB

# %%
new_col=df_agg_bookings.apply(lambda row:row["successful_bookings"]/row["capacity"],axis=1)
df_agg_bookings=df_agg_bookings.assign(occ_pct=new_col.values)
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667

# %% [markdown]
# What is the average occupancy rate

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean()
# Out:
# room_category
# RT1    0.582242
# RT2    0.580402
# RT3    0.580283
# RT4    0.593002
# Name: occ_pct, dtype: float64
