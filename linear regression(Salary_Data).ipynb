# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("/content/Salary_Data.csv")

# %%
df1
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df1.shape
# Out:
# (30, 2)

# %%
plt.scatter(df1.YearsExperience,df1.Salary)
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
df1.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df1.iloc[0]
# Out:
# YearsExperience        1.1
# Salary             39343.0
# Name: 0, dtype: float64

# %%
df1.iloc[:10,1]   #only salary column
# Out:
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# Name: Salary, dtype: int64

# %%
df1.iloc[:3,0]  #only experience column
# Out:
# 0    1.1
# 1    1.3
# 2    1.5
# Name: YearsExperience, dtype: float64

# %%
df1.iloc[5:-1]
# Out:
#     YearsExperience  Salary
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391

# %%
df1.iloc[:6]
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642

# %%
x=df1.iloc[:,:-1].values   #iloc fubction=is like index location

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
y=df1.iloc[:,1].values

# %%
print(y)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
plt.plot(x,y,'c')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
from sklearn.model_selection import train_test_split        #splitting the data into training and testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)     #random state ,randomly distributes the data selects one
                                                                                  #more randomness decreases the accuracy
                                                                                  # large data=accuracy increases

# %%
print(x_train)
# Out:
# [[ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]

# %%
print(x_test)
# Out:
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]]

# %%
print(y_train)
# Out:
# [ 56642  66029  64445  61111 113812  91738  46205 121872  60150  39891
#   81363  93940  57189  54445 105582  43525  39343  98273  67938  56957]

# %%
print(x.shape)
print(y.shape)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (30, 1)
# (30,)
# (20, 1)
# (10, 1)
# (20,)
# (10,)

# %%
print("X Shape:",x.shape)
print("Y shape:",y.shape)
print("X Train",x_train.shape)
print("X Test:",x_test.shape)
print("Y Train:",y_train.shape)
print("Y Test:",y_test.shape)
# Out:
# X Shape: (30, 1)
# Y shape: (30,)
# X Train (20, 1)
# X Test: (10, 1)
# Y Train: (20,)
# Y Test: (10,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)             #y=mx+c
print(regressor.intercept_)    #c
print(regressor.coef_)           #m
print(regressor)
# Out:
# 26816.192244031183
# [9345.94244312]
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
df1_x_test=pd.DataFrame(x_test)
df1_y_test=pd.DataFrame(y_test)
df1_y_pred=pd.DataFrame(y_pred)

df1_diff=df1_y_test-df1_y_pred
y_test_pred=pd.concat([df1_x_test,df1_y_test,df1_y_pred],axis=1)
y_test_pred["Difference"]=df1_diff

# %%
df1_diff
# Out:
#              0
# 0 -3104.105909
# 1  -688.399408
# 2 -8053.556261
# 3   -47.367772
# 4  1366.354546
# 5  1305.108501
# 6 -3902.239698
# 7 -8405.962017
# 8  6738.312807
# 9   652.862455

# %%
df1_x_test=pd.DataFrame(x_test,columns=['Experience'])            #new column for checking accuracy of our model
df1_y_test=pd.DataFrame(y_test,columns=['Salary'])
df1_y_pred=pd.DataFrame(y_pred,columns=['Prediction'])

df1_diff=df1_y_test-df1_y_pred
y_test_pred=pd.concat([df1_x_test,df1_y_test,df1_y_pred],axis=1)
y_test_pred["Difference"]=y_test_pred['Salary']-y_test_pred['Prediction']
y_test_pred
# Out:
#    Experience  Salary     Prediction   Difference
# 0         1.5   37731   40835.105909 -3104.105909
# 1        10.3  122391  123079.399408  -688.399408
# 2         4.1   57081   65134.556261 -8053.556261
# 3         3.9   63218   63265.367772   -47.367772
# 4         9.5  116969  115602.645454  1366.354546
# 5         8.7  109431  108125.891499  1305.108501
# 6         9.6  112635  116537.239698 -3902.239698
# 7         4.0   55794   64199.962017 -8405.962017
# 8         5.3   83088   76349.687193  6738.312807
# 9         7.9  101302  100649.137545   652.862455

# %%
from sklearn.metrics import r2_score          #r2_score gives the accuracy of our model
r2_score(y_test,y_pred)
# Out:
# 0.9749154407708353

# %%
y_test_pred
# Out:
#    Experience  Salary     Prediction   Difference
# 0         1.5   37731   40835.105909 -3104.105909
# 1        10.3  122391  123079.399408  -688.399408
# 2         4.1   57081   65134.556261 -8053.556261
# 3         3.9   63218   63265.367772   -47.367772
# 4         9.5  116969  115602.645454  1366.354546
# 5         8.7  109431  108125.891499  1305.108501
# 6         9.6  112635  116537.239698 -3902.239698
# 7         4.0   55794   64199.962017 -8405.962017
# 8         5.3   83088   76349.687193  6738.312807
# 9         7.9  101302  100649.137545   652.862455

# %%
y_pred_f=regressor.predict(x)     #taking entire data set
y_pred_f
# Out:
# array([ 37096.72893147,  38965.91742009,  40835.10590871,  45508.07713028,
#         47377.2656189 ,  53919.42532909,  54854.0195734 ,  56723.20806202,
#         56723.20806202,  61396.17928358,  63265.36777221,  64199.96201652,
#         64199.96201652,  65134.55626083,  68872.93323808,  72611.31021533,
#         74480.49870396,  76349.68719258,  81957.25265845,  82891.84690277,
#         90368.60085726,  93172.3835902 , 100649.1375447 , 103452.92027763,
#        108125.8914992 , 110929.67423213, 115602.64545369, 116537.23969801,
#        123079.39940819, 124948.58789682])

# %%
y_pred_final=pd.DataFrame(y_pred_f,columns=['Prediction'])
y_pred_final
# Out:
#        Prediction
# 0    37096.728931
# 1    38965.917420
# 2    40835.105909
# 3    45508.077130
# 4    47377.265619
# 5    53919.425329
# 6    54854.019573
# 7    56723.208062
# 8    56723.208062
# 9    61396.179284
# 10   63265.367772
# 11   64199.962017
# 12   64199.962017
# 13   65134.556261
# 14   68872.933238
# 15   72611.310215
# 16   74480.498704
# 17   76349.687193
# 18   81957.252658
# 19   82891.846903
# 20   90368.600857
# 21   93172.383590
# 22  100649.137545
# 23  103452.920278
# 24  108125.891499
# 25  110929.674232
# 26  115602.645454
# 27  116537.239698
# 28  123079.399408
# 29  124948.587897

# %%
result=pd.concat([df1,y_pred_final],axis=1)
result
# Out:
#     YearsExperience  Salary     Prediction
# 0               1.1   39343   37096.728931
# 1               1.3   46205   38965.917420
# 2               1.5   37731   40835.105909
# 3               2.0   43525   45508.077130
# 4               2.2   39891   47377.265619
# 5               2.9   56642   53919.425329
# 6               3.0   60150   54854.019573
# 7               3.2   54445   56723.208062
# 8               3.2   64445   56723.208062
# 9               3.7   57189   61396.179284
# 10              3.9   63218   63265.367772
# 11              4.0   55794   64199.962017
# 12              4.0   56957   64199.962017
# 13              4.1   57081   65134.556261
# 14              4.5   61111   68872.933238
# 15              4.9   67938   72611.310215
# 16              5.1   66029   74480.498704
# 17              5.3   83088   76349.687193
# 18              5.9   81363   81957.252658
# 19              6.0   93940   82891.846903
# 20              6.8   91738   90368.600857
# ...

# %%
acc=r2_score(y,y_pred_f)
acc
# Out:
# 0.9565349708076958

# %%
regressor.predict([[5]])         #for y yearsexperience what could be the salary
